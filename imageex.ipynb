# %%
import numpy as np
from PIL import Image
from numpy import asarray
import matplotlib.pylab as plt
# %matplotlib inline
omg=Image.open('Otree.jpg')
print(omg.format)
print(omg.size)
print(omg.mode)
numpydata= asarray(omg)
print(type(numpydata))
print(numpydata.shape)
omg = plt.imshow(omg)
crop_img=omg[20:199,:]
omg = plt.imshow(crop_img)
# Out:
# JPEG
# (940, 627)
# RGB
# <class 'numpy.ndarray'>
# (627, 940, 3)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-69c276a062b2> in <cell line: 14>()
#      12 print(numpydata.shape)
#      13 omg = plt.imshow(omg)
# ---> 14 crop_img=omg[20:199,:200,:]
#      15 omg = plt.imshow(crop_img)
#      16
#
# TypeError: 'AxesImage' object is not subscriptable
